# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from glob import glob

# %%
# File to Load (Remember to Change These)
schools_data = ("../Resources/schools_complete.csv") 
students_data = ("../Resources/students_complete.csv")
print (schools_data)
print (students_data)
# Out:
# ../Resources/schools_complete.csv
# ../Resources/students_complete.csv

# %%
# Read School Data File and store into Pandas DataFrames
schools_data_df = pd.read_csv(schools_data)
schools_data_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Read Student Data File and store into Pandas DataFrames
students_data_df = pd.read_csv(students_data)
students_data_df.head(20)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# 13          13       William Long      M   9th  Huang High School
# 14          14       Tammy Hebert      F  10th  Huang High School
# 15          15  Dr. Jordan Carson      M  11th  Huang High School
# 16          16      Donald Zamora      M   9th  Huang High School
# 17          17  Kimberly Santiago      F   9th  Huang High School
# 18          18      Kevin Stevens      M   9th  Huang High School
# 19          19       Brandi Lyons      F   9th  Huang High School
#
#     reading_score  math_score
# 0              66          79
# 1              94          61
# 2              90          60
# 3              67          58
# 4              97          84
# 5              94          94
# 6              82          80
# 7              96          69
# 8              95          87
# 9              96          84
# 10             90          70
# 11             78          77
# 12             64          79
# 13             71          79
# 14             85          67
# 15             94          88
# 16             88          55
# 17             74          75
# 18             64          69
# 19             89          80

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(left=students_data_df, right=schools_data_df, how="left", left_on="school_name", right_on="school_name")
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
# Clean the Data
print(school_data_complete.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.6+ MB
# None

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Explore Data
school_data_complete = school_data_complete
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
# Total Schools
total_schools = (school_data_complete['school_name']).nunique()

# %%
# Total Students
total_students = (school_data_complete['Student ID']).nunique()

# %%
# Total Budget
total_budget = school_data_complete['budget'].sum()

# %%
# Average Math Score
avg_math_score = school_data_complete['math_score'].mean()

# %%
# Average Reading Score
avg_reading_score = school_data_complete['reading_score'].mean()

# %%
# Passing Math Percentage
passing_math = 100*len(school_data_complete[school_data_complete['math_score']>=70]) / total_students
#https://blog.softhints.com/pandas-count-percentage-value-column/
#passing_math_percent100 = passing_math.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
#gives the same answer but with the percentage true and percentage false

# %%
# Passing Reading Percentage
passing_reading = 100*len(school_data_complete[school_data_complete['reading_score']>=70]) / total_students
#https://blog.softhints.com/pandas-count-percentage-value-column/
#passing_reading_percent100 = passing_reading.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
#gives the same answer but with the percentage true and percentage false

# %%
#Overall Passing Percentage
overall_passing = (passing_math / passing_reading) / 2
over_all_rate = (overall_passing) * 100

# %%
district_summary = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Average Math Score": [avg_math_score],
    "Average Reading Score" : [avg_reading_score],
    "% Passing Math": [passing_math],
    "% Passing Reading": [passing_reading],
    "% Overall Passing": [over_all_rate]},  
    columns=["Total Schools", "Total Students", "Total Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"])

district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170   82932329558           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          43.692353

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#School Names
grouped_school_names = school_data_complete.groupby('school_name')
grouped_school_names

# %%
#School Type 
school_type = grouped_school_names['type'].unique().str[0]

# %%
#Total Students in Each School
school_students = (grouped_school_names['Student ID']).count()

# %%
# Total budget for each school
schools_budget = (grouped_school_names['budget']).unique()

# %%
# School expenditures per student
per_student_budget = schools_budget / school_students

# %%
#Average Math Score per School
school_avg_math_score = grouped_school_names['math_score'].mean()

# %%
#Average reading Score per School
school_avg_reading_score = grouped_school_names['reading_score'].mean()

# %%
# Students Passing math totals by school
#school_math_pass = 100*len(schools_data_complete_df[schools_data_complete_df['reading_score']>=70]) / total_students

passing_math_df = school_data_complete[school_data_complete['math_score']>=70]

perc_passing_math_df = (passing_math_df.groupby('school_name').count()['math_score'] / school_students)*100

# %%
# Passing reading totals by school
passing_reading_df = school_data_complete[school_data_complete['reading_score']>=70]

perc_passing_reading_df = (passing_reading_df.groupby('school_name').count()['reading_score'] / school_students)*100

# %%
#Passing math percentage by school
over_all_sch_avg = (perc_passing_math_df / perc_passing_reading_df) * 100

# %%
# School Summary
grouped_school_names_df = pd.DataFrame({
    "School Type": school_type,
    "Total Students": school_students,
    "Total School Budget": avg_math_score,
    "Per Student Budget": schools_budget,
    "Average Math Score": school_avg_math_score,
    "Average Reading Score": school_avg_reading_score,
    "% Passing Math": perc_passing_math_df,
    "% Passing Reading": perc_passing_reading_df,
    "% Overall Passing": over_all_sch_avg,},  
    columns=["School Type", "Total Students", "Total School Budget", "Per Student Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"])

grouped_school_names_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976            78.985371
# Cabrera High School       Charter            1858            78.985371
# Figueroa High School     District            2949            78.985371
# Ford High School         District            2739            78.985371
# Griffin High School       Charter            1468            78.985371
# Hernandez High School    District            4635            78.985371
# Holden High School        Charter             427            78.985371
# Huang High School        District            2917            78.985371
# Johnson High School      District            4761            78.985371
# Pena High School          Charter             962            78.985371
# Rodriguez High School    District            3999            78.985371
# Shelton High School       Charter            1761            78.985371
# Thomas High School        Charter            1635            78.985371
# Wilson High School        Charter            2283            78.985371
# Wright High School        Charter            1800            78.985371
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Bailey High School             [3124928]           77.048432
# Cabrera High School            [1081356]           83.061895
# Figueroa High School           [1884411]           76.711767
# Ford High School               [1763916]           77.102592
# Griffin High School             [917500]           83.351499
# Hernandez High School          [3022020]           77.289752
# Holden High School              [248087]           83.803279
# Huang High School              [1910635]           76.629414
# Johnson High School            [3094650]           77.072464
# Pena High School                [585858]           83.839917
# Rodriguez High School          [2547363]           76.842711
# Shelton High School            [1056600]           83.359455
# Thomas High School             [1043130]           83.418349
# Wilson High School             [1319574]           83.274201
# Wright High School             [1049400]           83.682222
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.848930       93.272171
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing
# school_name
# Bailey High School
# %%
eleventh_grade = school_data_complete[school_data_complete['grade']=='11th']
eleventh_grade.head()
# Out:
#     Student ID       student_name gender grade        school_name  \
# 6            6      Sheena Carter      F  11th  Huang High School
# 15          15  Dr. Jordan Carson      M  11th  Huang High School
# 22          22   Kimberly Stewart      F  11th  Huang High School
# 24          24   Chelsea Griffith      F  11th  Huang High School
# 28          28        Kelly James      F  11th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget
# 6              82          80          0  District  2917  1910635
# 15             94          88          0  District  2917  1910635
# 22             99          84          0  District  2917  1910635
# 24             85          73          0  District  2917  1910635
# 28             73          55          0  District  2917  1910635

# %%
twelth_grade = school_data_complete[school_data_complete['grade']=='12th']
twelth_grade.head()
# Out:
#     Student ID       student_name gender grade        school_name  \
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 29          29       Nicole Brown      F  12th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget
# 1              94          61          0  District  2917  1910635
# 2              90          60          0  District  2917  1910635
# 3              67          58          0  District  2917  1910635
# 7              96          69          0  District  2917  1910635
# 29             90          88          0  District  2917  1910635

# %%
ninth_grade_group = ninth_grade.groupby('school_name')
ninth_avg_math_score = ninth_grade_group['math_score'].mean()
ninth_avg_math_score
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School       83.590022
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
tenth_grade_group = tenth_grade.groupby('school_name')
tenth_avg_math_score = tenth_grade_group['math_score'].mean()
tenth_avg_math_score
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
eleventh_grade_group = eleventh_grade.groupby('school_name')
eleventh_avg_math_score = eleventh_grade_group['math_score'].mean()
eleventh_avg_math_score
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
twelth_grade_group = twelth_grade.groupby('school_name')
twelth_avg_math_score = twelth_grade_group['math_score'].mean()
twelth_avg_math_score
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %%
# Merge into One DataFrame
grade1_df = pd.merge(left=ninth_avg_math_score, right=tenth_avg_math_score, how="left", left_on="school_name", right_on="school_name").
grade1_df
# Out:
#   File "<ipython-input-165-8eefe366a148>", line 2
#     grade1_df = pd.merge(left=ninth_avg_math_score, right=tenth_avg_math_score, how="left", left_on="school_name", right_on="school_name").
#                                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
# Rename grade1_df math score names from trenton3983.github.io
# make a copy
math_grade = grade1_df.copy()

# Create a new list of math scores
new_labels = ['math_score', 'math_score']
               
#Rename the columns with the new lables
math_grade.columns = new_labels

math_grade
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-62e22d60bb69> in <module>
#       1 # Rename grade1_df math score names from trenton3983.github.io
#       2 # make a copy
# ----> 3 math_grade = grade1_df.copy()
#       4
#       5 # Create a new list of math scores
#
# AttributeError: 'function' object has no attribute 'copy'

# %%
grade2_df = pd.merge(left=eleventh_avg_math_score, right=twelth_avg_math_score, how="left", left_on="school_name", right_on="school_name")
grade2_df
# Out:
#                        math_score_x  math_score_y
# school_name
# Bailey High School        77.515588     76.492218
# Cabrera High School       82.765560     83.277487
# Figueroa High School      76.884344     77.151369
# Ford High School          76.918058     76.179963
# Griffin High School       83.842105     83.356164
# Hernandez High School     77.136029     77.186567
# Holden High School        85.000000     82.855422
# Huang High School         76.446602     77.225641
# Johnson High School       77.491653     76.863248
# Pena High School          84.328125     84.121547
# Rodriguez High School     76.395626     77.690748
# Shelton High School       83.383495     83.778976
# Thomas High School        83.498795     83.497041
# Wilson High School        83.195326     83.035794
# Wright High School        83.836782     83.644986

# %%
# Rename grade2_df math score names
# make a copy
math_grade1 = grade2_df.copy()

# Create a new list of math scores
new_labels = ['math_score', 'math_score']
               
#Rename the columns with the new lables
math_grade1.columns = new_labels
math_grade1
# Out:
#                        math_score  math_score
# school_name
# Bailey High School      77.515588   76.492218
# Cabrera High School     82.765560   83.277487
# Figueroa High School    76.884344   77.151369
# Ford High School        76.918058   76.179963
# Griffin High School     83.842105   83.356164
# Hernandez High School   77.136029   77.186567
# Holden High School      85.000000   82.855422
# Huang High School       76.446602   77.225641
# Johnson High School     77.491653   76.863248
# Pena High School        84.328125   84.121547
# Rodriguez High School   76.395626   77.690748
# Shelton High School     83.383495   83.778976
# Thomas High School      83.498795   83.497041
# Wilson High School      83.195326   83.035794
# Wright High School      83.836782   83.644986

# %%
# Join math_score with math_score1 (columns with the same name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-7ddc8b4c77dc> in <module>
#       1 # Join math_score with math_score1 (columns with the same name)
# ----> 2 math_grade1.join(['school_name'], lsuffix='_left', rsuffix='_right', on=['school_names'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7896         else:
#    7897             if on is not None:
# -> 7898                 raise ValueError(
#    7899                     "Joining multiple DataFrames only supported for joining on index"
#    7900                 )
#
# ValueError: Joining multiple DataFrames only supported for joining on index

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
reading_by_grade = school_data_complete.groupby('grade')
reading_by_grade

# %%
grouped_reading_scores = reading_by_grade.mean()
grouped_reading_scores.sort_values('grade', ascending=False).head()
grouped_reading_scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
